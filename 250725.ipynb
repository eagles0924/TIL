# %%
import json

book_json = open('C:/Workspace_SB/SSAFY_pjt/250725_pjt1/pjt/pjt-01/영화/aladin/data/book.json', encoding="utf-8")
book = json.load(book_json)
book
# Out:
# {'title': '노인과 바다',
#  'link': 'http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=14522431&amp;partner=openAPI&amp;start=api',
#  'author': '어니스트 헤밍웨이 (지은이), 김욱동 (옮긴이)',
#  'description': "노벨 문학상, 퓰리처상 수상 작가, 20세기 미국 문학을 개척한 작가 어니스트 헤밍웨이의 대표작. 미국 현대 문학의 개척자라 불리는 헤밍웨이는 제1차 세계대전 후 삶의 좌표를 잃어버린 '길 잃은 세대'를 대표하는 작가이다. '민음사 세계문학전집' 278권으로 출간된 &lt;노인과 바다&gt;는 헤밍웨이의 마지막 소설로, 작가 고유의 소설 수법과 실존 철학이 짧은 분량 안에 집약되어 있다.",
#  'isbn': '8937462788',
#  'isbn13': '9788937462788',
#  'id': 14522431,
#  'priceSales': 7200,
#  'priceStandard': 8000,
#  'mallType': 'BOOK',
#  'stockStatus': '',
#  'mileage': 400,
#  'cover': 'https://image.aladin.co.kr/product/1452/24/coversum/8937462788_2.jpg',
#  'categoryId': [151128, 50919],
#  'publisher': '민음사',
#  'salesPoint': 32482,
#  'adult': False,
#  'fixedPrice': True,
#  'seriesInfo': {'seriesId': 13679,
#   'seriesLink': 'http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=13679&amp;partner=openAPI',
#   'seriesName': '민음사 세계문학전집 278'},
# ...

# %%
book_need['categoryName'] = book_need.pop('categoryId')

# %%
book_need.insert(1, ('categoryName','공포'))
book_need
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 book_need.insert(1, ('categoryName','공포'))
#       2 book_need
#
# AttributeError: 'dict' object has no attribute 'insert'

# %%
print(book_need)
# Out:
# {'author': '어니스트 헤밍웨이 (지은이), 김욱동 (옮긴이)', 'categoryId': [151128, 50919], 'cover': 'https://image.aladin.co.kr/product/1452/24/coversum/8937462788_2.jpg', 'description': "노벨 문학상, 퓰리처상 수상 작가, 20세기 미국 문학을 개척한 작가 어니스트 헤밍웨이의 대표작. 미국 현대 문학의 개척자라 불리는 헤밍웨이는 제1차 세계대전 후 삶의 좌표를 잃어버린 '길 잃은 세대'를 대표하는 작가이다. '민음사 세계문학전집' 278권으로 출간된 &lt;노인과 바다&gt;는 헤밍웨이의 마지막 소설로, 작가 고유의 소설 수법과 실존 철학이 짧은 분량 안에 집약되어 있다.", 'id': 14522431, 'priceSales': 7200, 'title': '노인과 바다'}

# %%
keys = ['author','categoryId','cover','description','id','priceSales','title']
book_need = {}
for key in keys:
    book_need[key] = book[key]
book_need
# Out:
# {'author': '어니스트 헤밍웨이 (지은이), 김욱동 (옮긴이)',
#  'categoryId': [151128, 50919],
#  'cover': 'https://image.aladin.co.kr/product/1452/24/coversum/8937462788_2.jpg',
#  'description': "노벨 문학상, 퓰리처상 수상 작가, 20세기 미국 문학을 개척한 작가 어니스트 헤밍웨이의 대표작. 미국 현대 문학의 개척자라 불리는 헤밍웨이는 제1차 세계대전 후 삶의 좌표를 잃어버린 '길 잃은 세대'를 대표하는 작가이다. '민음사 세계문학전집' 278권으로 출간된 &lt;노인과 바다&gt;는 헤밍웨이의 마지막 소설로, 작가 고유의 소설 수법과 실존 철학이 짧은 분량 안에 집약되어 있다.",
#  'id': 14522431,
#  'priceSales': 7200,
#  'title': '노인과 바다'}

# %%
book_need.pop('categoryId')
book_need
# Out:
# {'author': '어니스트 헤밍웨이 (지은이), 김욱동 (옮긴이)',
#  'cover': 'https://image.aladin.co.kr/product/1452/24/coversum/8937462788_2.jpg',
#  'description': "노벨 문학상, 퓰리처상 수상 작가, 20세기 미국 문학을 개척한 작가 어니스트 헤밍웨이의 대표작. 미국 현대 문학의 개척자라 불리는 헤밍웨이는 제1차 세계대전 후 삶의 좌표를 잃어버린 '길 잃은 세대'를 대표하는 작가이다. '민음사 세계문학전집' 278권으로 출간된 &lt;노인과 바다&gt;는 헤밍웨이의 마지막 소설로, 작가 고유의 소설 수법과 실존 철학이 짧은 분량 안에 집약되어 있다.",
#  'id': 14522431,
#  'priceSales': 7200,
#  'title': '노인과 바다'}

# %%
for id in book_need['categoryId']:
    if id == category
# Out:
# [151128, 50919]

# %%
book_need[book_need['categoryId']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 book_need[book_need['categoryId']]
#
# TypeError: unhashable type: 'list'

# %%
categories = [{'id': 31916, 'name': '과학'},
 {'id': 31908, 'name': '에세이 / 수필'},
 {'id': 151138, 'name': '자기계발'},
 {'id': 153690, 'name': '서양철학'},
 {'id': 151128, 'name': '문학'},
 {'id': 50919, 'name': '영미소설'},
 {'id': 89481, 'name': '외국 과학소설'},
 {'id': 50922, 'name': '독일소설'},
 {'id': 70216, 'name': '성공학'},
 {'id': 51786, 'name': '육아 일반'},
 {'id': 51082, 'name': '건축'},
 {'id': 51381, 'name': '인문'},
 {'id': 51260, 'name': '프랑스 문학'},
 {'id': 50982, 'name': '미술사'},
 {'id': 51545, 'name': '인류학'},
 {'id': 51205, 'name': '생명과학'},
 {'id': 51310, 'name': '우주과학'},
 {'id': 50921, 'name': '철학'},
 {'id': 51449, 'name': '윤리학'},
 {'id': 2721, 'name': '컴퓨터 공학'}]

# %%
categories[1]['id']
# Out:
# 31908

# %%
for id in book['categoryId']:
    categoryName = [category['name'] for category in categories if id == category['id']]
# Out:
# ['문학', '영미소설']

# %%
book_need = dict()
book_need
# Out:
# {}

# %%
book
# Out:
# {'title': '노인과 바다',
#  'link': 'http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=14522431&amp;partner=openAPI&amp;start=api',
#  'author': '어니스트 헤밍웨이 (지은이), 김욱동 (옮긴이)',
#  'description': "노벨 문학상, 퓰리처상 수상 작가, 20세기 미국 문학을 개척한 작가 어니스트 헤밍웨이의 대표작. 미국 현대 문학의 개척자라 불리는 헤밍웨이는 제1차 세계대전 후 삶의 좌표를 잃어버린 '길 잃은 세대'를 대표하는 작가이다. '민음사 세계문학전집' 278권으로 출간된 &lt;노인과 바다&gt;는 헤밍웨이의 마지막 소설로, 작가 고유의 소설 수법과 실존 철학이 짧은 분량 안에 집약되어 있다.",
#  'isbn': '8937462788',
#  'isbn13': '9788937462788',
#  'id': 14522431,
#  'priceSales': 7200,
#  'priceStandard': 8000,
#  'mallType': 'BOOK',
#  'stockStatus': '',
#  'mileage': 400,
#  'cover': 'https://image.aladin.co.kr/product/1452/24/coversum/8937462788_2.jpg',
#  'categoryId': [151128, 50919],
#  'publisher': '민음사',
#  'salesPoint': 32482,
#  'adult': False,
#  'fixedPrice': True,
#  'seriesInfo': {'seriesId': 13679,
#   'seriesLink': 'http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=13679&amp;partner=openAPI',
#   'seriesName': '민음사 세계문학전집 278'},
# ...

# %%
books_json = open('C:/Workspace_SB/SSAFY_pjt/250725_pjt1/pjt/pjt-01/영화/aladin/data/books.json', encoding='utf-8')
books = json.load(books_json)

keys = ['author', 'categoryId', 'cover', 'description', 'id', 'priceSales', 'title']
books_need = list()
for book in books:
    book_need = dict()
    for key in keys:
        book_need[key] = book[key]
    books_need.append(book_need)
books_need
# Out:
# [{'author': '제인 오스틴 (지은이), 윤지관, 전승희 (옮긴이)',
#   'categoryId': [151128, 50919],
#   'cover': 'https://image.aladin.co.kr/product/43/68/coversum/8937460882_3.jpg',
#   'description': '제인 오스틴의 대표작 <오만과 편견>이 보다 정확하고 말끔한 번역으로 재출간됐다. 역자인 윤지관과 전승희는 10여 년에 걸친 기간 동안 철저한 원문대조를 통해, 본래의 의미와 문체를 생생하게 되살려내기 위해 노력했다고.',
#   'id': 436838,
#   'priceSales': 11700,
#   'title': '오만과 편견'},
#  {'author': '어니스트 헤밍웨이 (지은이), 김욱동 (옮긴이)',
#   'categoryId': [151128, 50919],
#   'cover': 'https://image.aladin.co.kr/product/1452/24/coversum/8937462788_2.jpg',
#   'description': "노벨 문학상, 퓰리처상 수상 작가, 20세기 미국 문학을 개척한 작가 어니스트 헤밍웨이의 대표작. 미국 현대 문학의 개척자라 불리는 헤밍웨이는 제1차 세계대전 후 삶의 좌표를 잃어버린 '길 잃은 세대'를 대표하는 작가이다. '민음사 세계문학전집' 278권으로 출간된 &lt;노인과 바다&gt;는 헤밍웨이의 마지막 소설로, 작가 고유의 소설 수법과 실존 철학이 짧은 분량 안에 집약되어 있다.",
#   'id': 14522431,
#   'priceSales': 7200,
#   'title': '노인과 바다'},
#  {'author': '서머싯 몸 (지은이), 송무 (옮긴이)',
#   'categoryId': [151128, 50919],
# ...

# %%
import os
book_rank_list = os.listdir(r'C:\Workspace_SB\SSAFY_pjt\250725_pjt1\pjt\pjt-01\영화\aladin\data\books')

# %%
for idx in book_rank_list:
    print(idx[:-5])
# Out:
# 1020939
# 14522431
# 170482558
# 212246612
# 237763
# 256532
# 268444562
# 282733777
# 314240466
# 315176143
# 317444541
# 34083680
# 38084277
# 436838
# 55182423
# 60836103
# 75760
# 870950
# 927185
# 98708362

# %%
idx = 5
str(idx)+'.json'
# Out:
# '5.json'

# %%
books
# Out:
# [{'title': '오만과 편견',
#   'link': 'http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=436838&amp;partner=openAPI&amp;start=api',
#   'author': '제인 오스틴 (지은이), 윤지관, 전승희 (옮긴이)',
#   'description': '제인 오스틴의 대표작 <오만과 편견>이 보다 정확하고 말끔한 번역으로 재출간됐다. 역자인 윤지관과 전승희는 10여 년에 걸친 기간 동안 철저한 원문대조를 통해, 본래의 의미와 문체를 생생하게 되살려내기 위해 노력했다고.',
#   'isbn': '8937460882',
#   'isbn13': '9788937460883',
#   'id': 436838,
#   'priceSales': 11700,
#   'priceStandard': 13000,
#   'mallType': 'BOOK',
#   'stockStatus': '',
#   'mileage': 650,
#   'cover': 'https://image.aladin.co.kr/product/43/68/coversum/8937460882_3.jpg',
#   'categoryId': [151128, 50919],
#   'publisher': '민음사',
#   'salesPoint': 47947,
#   'adult': False,
#   'fixedPrice': True,
#   'seriesInfo': {'seriesId': 13679,
#    'seriesLink': 'http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=13679&amp;partner=openAPI',
#    'seriesName': '민음사 세계문학전집 88'},
#   'subInfo': {'ebookList': [{'itemId': 18094741,
#      'isbn': 'E893746088',
# ...

# %%
for i in range(10):
    print(i)
    break
# Out:
# 0

# %%
a = '2023-01-24'
a[:4]
# Out:
# '2023'
